# %%
from abc import ABCMeta, abstractmethod

# %%
class PopulationClass:
    
    __metaclass__ = ABCMeta
    
    t = 0
    
    def __init__(self, i, j):
        self.i = i
        self.j = j
    
    @abstractmethod
    def height(self):
        pass
    
    @abstractmethod
    def recource_capacity(self):
        pass
    
    @abstractmethod
    def f(self):
        pass
    
    def max_capacity(self):
        self.f(self.height())
        
    def energy_pulse(self, alfa1, alfa2, betta1, betta2, gamma1, gamma2, psi1, psi2, delta_x, delta_y, i0, j0):
        pass
        
    def speed_height(self, t):
